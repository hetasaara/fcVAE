# %% [markdown]
# # AML flow cytometry analysis

# %%
import numpy as np
import torch
from torch.autograd import Variable
from fcvae_dataset import load_data
from fcvae_model import VAE, Encoder, Decoder, Classifier
from fcvae_trainer import fcTrainer
from fcvae_plot import CellPlotter2D, plot_joint_aml, plot_shared_markers_aml, plot_imputed_values_set
from umap import UMAP
import flowkit as fk
import glob

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Torch version:", torch.__version__)
print("Device:", device)
# Out:
# Torch version: 1.2.0
# Device: cpu

# %% [markdown]
# ## 1. Load data

# %%
filepath1 = "/scratch/cs/csb/projects/single-cell-analysis/FCM/AML_FCM/data_files/"

batch_size = 256         # number of data points in each batch
n_epochs = 30           # times to run the model on complete data
input_dim = 7     # size of each input
hidden_dim = 128        # hidden dimension
latent_dim = 4        # latent vector dimension
lr = 1e-3              # learning rate
n_head = 2
n_shared = 3
missing = 4

datasets = load_data(filepath1)

input_dim_list = []
output_dim_list = []
train_iterators = []
test_iterators = []
train_cells = 0
test_cells = 0
for tube in datasets:
    input_dim_list.append(len(tube[0].columns))
    output_dim_list.append(len(tube[0].columns)+missing)
    train_iterators.append(tube[3])
    test_iterators.append(tube[4])
    train_cells += tube[1].nb_cells
    test_cells += tube[2].nb_cells

N_train = int(train_cells/n_head)
N_test = int(test_cells/n_head)
print('Training set size:', N_train)
print('Test set size:', N_test)
# Out:
# Training set size: 27000
# Test set size: 3000

# %% [markdown]
# ## 2. Create a model

# %%
# Encoder
encoder = Encoder(n_head, input_dim_list, hidden_dim, latent_dim)

# Decoder
decoder = Decoder(latent_dim, hidden_dim, output_dim_list, n_head)

# VAE
model = VAE(encoder, decoder).to(device)

# Discriminator
discriminator = Classifier(latent_dim, hidden_dim, n_head) 

print("n_tubes:", n_head)
print("n_shared:", n_shared)
print("n_other:", missing)
print("output_dim:", output_dim_list[0])
print("encoder_dims:", input_dim_list)
# Out:
# n_tubes: 2
# n_shared: 3
# n_other: 4
# output_dim: 11
# encoder_dims: [7, 7]

# %% [markdown]
# ## 3. Train the model

# %%
# Create trainer
trainer = fcTrainer(
            model,
            discriminator,
            train_loaders = train_iterators,
            test_loaders = test_iterators,
            N_train = N_train,
            N_test = N_test,
            dloss_weight = 10,
            device = device,
            n_epochs = n_epochs,
            print_frequency = 1,
            optimizer_kwargs = dict(lr = lr)
)
# Out:
# 04/03/2020 21:58:57 [INFO]: Creating a trainer on device `cpu`

# %%
# Run training
trainer.train()
# Out:
# 04/03/2020 21:58:57 [INFO]: TRAINING STARTED (n_epochs = 30).
# 04/03/2020 21:59:22 [INFO]: Epoch: 00, VAE loss: (66.46969, 27.71952), Discriminator loss: (0.12769, 0.18396)
# 04/03/2020 21:59:37 [INFO]: Epoch: 01, VAE loss: (31.71332, 22.59206), Discriminator loss: (0.06154, 0.1987)
# 04/03/2020 21:59:53 [INFO]: Epoch: 02, VAE loss: (28.89975, 19.43932), Discriminator loss: (0.05133, 0.21196)
# 04/03/2020 22:00:08 [INFO]: Epoch: 03, VAE loss: (26.52956, 20.31269), Discriminator loss: (0.06874, 0.21824)
# 04/03/2020 22:00:24 [INFO]: Epoch: 04, VAE loss: (25.09823, 18.57852), Discriminator loss: (0.08249, 0.21247)
# 04/03/2020 22:00:39 [INFO]: Epoch: 05, VAE loss: (24.2446, 16.81028), Discriminator loss: (0.08684, 0.2182)
# 04/03/2020 22:00:55 [INFO]: Epoch: 06, VAE loss: (23.07025, 17.83473), Discriminator loss: (0.10188, 0.22209)
# 04/03/2020 22:01:10 [INFO]: Epoch: 07, VAE loss: (23.08496, 15.9664), Discriminator loss: (0.11087, 0.21105)
# 04/03/2020 22:01:26 [INFO]: Epoch: 08, VAE loss: (22.50649, 16.40997), Discriminator loss: (0.11858, 0.20781)
# 04/03/2020 22:01:41 [INFO]: Epoch: 09, VAE loss: (21.76731, 16.84105), Discriminator loss: (0.12041, 0.2141)
# 04/03/2020 22:01:57 [INFO]: Epoch: 10, VAE loss: (21.55392, 16.67635), Discriminator loss: (0.12832, 0.21058)
# 04/03/2020 22:02:12 [INFO]: Epoch: 11, VAE loss: (21.08563, 16.15675), Discriminator loss: (0.12989, 0.20864)
# 04/03/2020 22:02:28 [INFO]: Epoch: 12, VAE loss: (20.95119, 17.38378), Discriminator loss: (0.13144, 0.21011)
# 04/03/2020 22:02:43 [INFO]: Epoch: 13, VAE loss: (20.5301, 14.46855), Discriminator loss: (0.13391, 0.20875)
# 04/03/2020 22:02:58 [INFO]: Epoch: 14, VAE loss: (20.3859, 14.49665), Discriminator loss: (0.12972, 0.208)
# 04/03/2020 22:03:14 [INFO]: Epoch: 15, VAE loss: (20.07545, 15.74148), Discriminator loss: (0.13469, 0.20817)
# 04/03/2020 22:03:29 [INFO]: Epoch: 16, VAE loss: (19.88082, 13.76861), Discriminator loss: (0.13465, 0.2106)
# 04/03/2020 22:03:45 [INFO]: Epoch: 17, VAE loss: (19.70222, 13.7589), Discriminator loss: (0.12863, 0.20971)
# 04/03/2020 22:04:00 [INFO]: Epoch: 18, VAE loss: (19.47958, 14.15843), Discriminator loss: (0.13519, 0.20755)
# 04/03/2020 22:04:16 [INFO]: Epoch: 19, VAE loss: (19.20797, 15.81867), Discriminator loss: (0.13378, 0.20937)
# 04/03/2020 22:04:31 [INFO]: Epoch: 20, VAE loss: (19.15705, 15.47864), Discriminator loss: (0.13882, 0.21129)
# 04/03/2020 22:04:47 [INFO]: Epoch: 21, VAE loss: (18.933, 14.29653), Discriminator loss: (0.13394, 0.20832)
# 04/03/2020 22:05:02 [INFO]: Epoch: 22, VAE loss: (18.70231, 14.14956), Discriminator loss: (0.13205, 0.2068)
# 04/03/2020 22:05:17 [INFO]: Epoch: 23, VAE loss: (18.44301, 15.92482), Discriminator loss: (0.13626, 0.21502)
# 04/03/2020 22:05:33 [INFO]: Epoch: 24, VAE loss: (18.58517, 13.01174), Discriminator loss: (0.13861, 0.21493)
# 04/03/2020 22:05:48 [INFO]: Epoch: 25, VAE loss: (18.30054, 15.0376), Discriminator loss: (0.13148, 0.21346)
# 04/03/2020 22:06:04 [INFO]: Epoch: 26, VAE loss: (18.41157, 12.98024), Discriminator loss: (0.14055, 0.21031)
# 04/03/2020 22:06:19 [INFO]: Epoch: 27, VAE loss: (18.14515, 13.20723), Discriminator loss: (0.14076, 0.20832)
# 04/03/2020 22:06:35 [INFO]: Epoch: 28, VAE loss: (18.0543, 13.32899), Discriminator loss: (0.13685, 0.21605)
# 04/03/2020 22:06:50 [INFO]: Epoch: 29, VAE loss: (17.89597, 14.3796), Discriminator loss: (0.13935, 0.21705)
# 04/03/2020 22:06:50 [INFO]: TRAINING FINISHED.

# %% [markdown]
# ## 4. Visualization

# %%
trainer.plot()
trainer.plot_probs()

# %%
latents = []

trainer.vae.eval()
for i in range(n_head):
    data = Variable(torch.from_numpy(datasets[i][0].to_numpy()), requires_grad=False)
    latents.append(model.get_z(data.float(), i).data.numpy())
latent2d = UMAP().fit_transform(np.concatenate(latents))

plot_joint_aml(trainer, latent2d, latents)
plot_shared_markers_aml(trainer, latent2d, latents, datasets)
# Out:
# /home/hiltunh3/.conda/envs/scvi/lib/python3.6/site-packages/numba/compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../../../../../home/hiltunh3/.conda/envs/scvi/lib/python3.6/site-packages/umap/rp_tree.py", line 135:
# @numba.njit(fastmath=True, nogil=True, parallel=True)
# def euclidean_random_projection_split(data, indices, rng_state):
# ^
#
#   self.func_ir.loc))
# /home/hiltunh3/.conda/envs/scvi/lib/python3.6/site-packages/umap/nndescent.py:92: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../../../../../home/hiltunh3/.conda/envs/scvi/lib/python3.6/site-packages/umap/utils.py", line 409:
# @numba.njit(parallel=True)
# def build_candidates(current_graph, n_vertices, n_neighbors, max_candidates, rng_state):
# ^
#
#   current_graph, n_vertices, n_neighbors, max_candidates, rng_state
# /home/hiltunh3/.conda/envs/scvi/lib/python3.6/site-packages/numba/compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../../../../../home/hiltunh3/.conda/envs/scvi/lib/python3.6/site-packages/umap/nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))

# %% [markdown]
# ## 5. Imputation

# %%
# marker names 
files = glob.glob(filepath1 + "*.txt")
titles = []
for i in range(len(files)):
    fcs = files[i][-8:-4]
    fcs_path = '/scratch/cs/csb/projects/single-cell-analysis/FCM/AML_FCM/Data/AML/FCS/'+fcs+'.FCS'
    sample = fk.Sample(fcs_path, subsample_count=None)
    features = sample.pns_labels[2:7]
    features.pop(2)
    titles.append(features)
print(titles) 
# visualize one set of imputed values, change later
#plot_imputed_values(trainer, latent2d, latents, datasets, titles)
plot_imputed_values_set(trainer, 0, latent2d, latents, datasets, titles)
# Out:
# /home/hiltunh3/.conda/envs/scvi/lib/python3.6/site-packages/flowio/flowdata.py:275: UserWarning: text in segment does not start and end with delimiter
#   warn("text in segment does not start and end with delimiter")
# [['CD15-FITC', 'CD13-PE', 'CD16-PC5', 'CD56-PC7'], ['CD14-FITC', 'CD11c-PE', 'CD64-PC5', 'CD33-PC7']]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-78d3f44905cf> in <module>
#      12 # visualize one set of imputed values, change later
#      13 #plot_imputed_values(trainer, latent2d, latents, datasets, titles)
# ---> 14 plot_imputed_values_set(trainer, 0, latent2d, latents, datasets, titles)
#
# NameError: name 'plot_imputed_values_set' is not defined

# %% [markdown]
# ## 6. Validation metrics

# %%
# Comparison: accuracy and log p(y)?

def validation_accuracy(model, discriminator, test_iterators):
    model.eval()
    discriminator.eval()
    probs = []
    for tensors in test_iterators:
        ps = []
        for head_id, batch in enumerate(tensors):
            z = model.get_z(batch.float(), head_id)
            p = discriminator.classify(z)
            ps.append(p)
        pr = torch.cat(ps).cpu().detach().numpy()
        probs.append(pr)
    return probs

def validation_loss(test_iterators, model, input_dim_list):
    # set the evaluation mode
    model.eval()
    n_head = len(input_dim_list)
    # test loss for the data
    test_losses = []
    
    for tensors in test_iterators:
        for head_id, x in enumerate(tensors): 
            # reshape the data
            x = x.view(-1, input_dim_list[head_id]) 
            x = x.float()
            x = x.to(device)

            # forward pass
            x_sample, z_mu, z_var = model(x, head_id)

            loss, recs, kls = model.loss(x_sample, x, z_mu, z_var, head_id)
            test_losses.append(loss)
    sum_loss = torch.stack(test_losses).sum()

    return sum_loss

runs = 5
accuracies = []
val_losses = []
for i in range(runs):
    trainer.train()
    acc = validation_accuracy(model, discriminator, zip(*test_iterators))
    acc = [item for sublist in acc for item in sublist]
    acc = [item for sublist in acc for item in sublist]

    correct = 0
    probs1 = acc[::2]
    for i in probs1[:N_test]:
        if i > 0.5:
            correct += 1
    for i in probs1[N_test:]:
        if i < 0.5:
            correct += 1

    accuracy = correct/len(acc[::2])
    accuracies.append(accuracy)
    val_loss = validation_loss(zip(*test_iterators), model, input_dim_list)/N_test
    val_losses.append(val_loss)
print(accuracies)
print(val_losses)
# Out:
# 04/03/2020 16:26:14 [INFO]: TRAINING STARTED (n_epochs = 30).
# 04/03/2020 16:26:39 [INFO]: Epoch: 00, VAE loss: (65.00318, 26.62234), Discriminator loss: (0.15395, 0.19281)
# 04/03/2020 16:26:57 [INFO]: Epoch: 01, VAE loss: (31.57738, 21.0753), Discriminator loss: (0.08514, 0.18994)
# 04/03/2020 16:27:16 [INFO]: Epoch: 02, VAE loss: (28.27621, 22.17976), Discriminator loss: (0.06751, 0.20976)
# 04/03/2020 16:27:34 [INFO]: Epoch: 03, VAE loss: (26.05268, 20.11083), Discriminator loss: (0.06428, 0.20041)
# 04/03/2020 16:27:52 [INFO]: Epoch: 04, VAE loss: (24.51838, 17.17264), Discriminator loss: (0.06096, 0.20311)
# 04/03/2020 16:28:10 [INFO]: Epoch: 05, VAE loss: (23.87543, 18.01659), Discriminator loss: (0.06067, 0.21299)
# 04/03/2020 16:28:29 [INFO]: Epoch: 06, VAE loss: (22.92946, 15.04566), Discriminator loss: (0.06395, 0.20623)
# 04/03/2020 16:28:47 [INFO]: Epoch: 07, VAE loss: (22.3499, 15.33871), Discriminator loss: (0.06112, 0.21148)
# 04/03/2020 16:29:05 [INFO]: Epoch: 08, VAE loss: (22.00009, 16.45406), Discriminator loss: (0.07115, 0.21343)
# 04/03/2020 16:29:23 [INFO]: Epoch: 09, VAE loss: (21.57133, 16.11097), Discriminator loss: (0.0748, 0.21616)
# 04/03/2020 16:29:41 [INFO]: Epoch: 10, VAE loss: (21.07562, 15.78749), Discriminator loss: (0.07545, 0.206)
# 04/03/2020 16:29:59 [INFO]: Epoch: 11, VAE loss: (20.93288, 15.56971), Discriminator loss: (0.08002, 0.20437)
# 04/03/2020 16:30:18 [INFO]: Epoch: 12, VAE loss: (20.36862, 15.59187), Discriminator loss: (0.08427, 0.21824)
# 04/03/2020 16:30:36 [INFO]: Epoch: 13, VAE loss: (20.19357, 15.30269), Discriminator loss: (0.09385, 0.21637)
# 04/03/2020 16:30:54 [INFO]: Epoch: 14, VAE loss: (20.18948, 15.45702), Discriminator loss: (0.09576, 0.20388)
# 04/03/2020 16:31:12 [INFO]: Epoch: 15, VAE loss: (19.61308, 17.09505), Discriminator loss: (0.09894, 0.2087)
# 04/03/2020 16:31:30 [INFO]: Epoch: 16, VAE loss: (19.68485, 15.15695), Discriminator loss: (0.10065, 0.20239)
# 04/03/2020 16:31:48 [INFO]: Epoch: 17, VAE loss: (19.19286, 13.92625), Discriminator loss: (0.10276, 0.21909)
# 04/03/2020 16:32:07 [INFO]: Epoch: 18, VAE loss: (19.02188, 13.71868), Discriminator loss: (0.1067, 0.22151)
# 04/03/2020 16:32:25 [INFO]: Epoch: 19, VAE loss: (18.96878, 14.62562), Discriminator loss: (0.10748, 0.21267)
# 04/03/2020 16:32:43 [INFO]: Epoch: 20, VAE loss: (19.00936, 14.7038), Discriminator loss: (0.10978, 0.21038)
# 04/03/2020 16:33:01 [INFO]: Epoch: 21, VAE loss: (18.64741, 15.44764), Discriminator loss: (0.11497, 0.21556)
# 04/03/2020 16:33:19 [INFO]: Epoch: 22, VAE loss: (18.56731, 16.36004), Discriminator loss: (0.10682, 0.20347)
# 04/03/2020 16:33:37 [INFO]: Epoch: 23, VAE loss: (18.28427, 15.41043), Discriminator loss: (0.11207, 0.20449)
# 04/03/2020 16:33:56 [INFO]: Epoch: 24, VAE loss: (18.28835, 13.2138), Discriminator loss: (0.11251, 0.2102)
# 04/03/2020 16:34:14 [INFO]: Epoch: 25, VAE loss: (18.09998, 13.31661), Discriminator loss: (0.11647, 0.21133)
# 04/03/2020 16:34:32 [INFO]: Epoch: 26, VAE loss: (17.86379, 14.33454), Discriminator loss: (0.11424, 0.20802)
# 04/03/2020 16:34:50 [INFO]: Epoch: 27, VAE loss: (17.91428, 13.86313), Discriminator loss: (0.11499, 0.20843)
# 04/03/2020 16:35:08 [INFO]: Epoch: 28, VAE loss: (17.71742, 15.07911), Discriminator loss: (0.11639, 0.20929)
# 04/03/2020 16:35:26 [INFO]: Epoch: 29, VAE loss: (17.4705, 14.60472), Discriminator loss: (0.11551, 0.20265)
# 04/03/2020 16:35:26 [INFO]: TRAINING FINISHED.
#
# 04/03/2020 16:35:27 [INFO]: TRAINING STARTED (n_epochs = 30).
# 04/03/2020 16:35:49 [INFO]: Epoch: 00, VAE loss: (17.51674, 13.83572), Discriminator loss: (0.12375, 0.21392)
# 04/03/2020 16:36:14 [INFO]: Epoch: 01, VAE loss: (17.43114, 14.73906), Discriminator loss: (0.11697, 0.21297)
# 04/03/2020 16:36:32 [INFO]: Epoch: 02, VAE loss: (17.47025, 16.28759), Discriminator loss: (0.12097, 0.22384)
# 04/03/2020 16:36:50 [INFO]: Epoch: 03, VAE loss: (17.07617, 14.58419), Discriminator loss: (0.11893, 0.21823)
# 04/03/2020 16:37:08 [INFO]: Epoch: 04, VAE loss: (17.08587, 13.10002), Discriminator loss: (0.12478, 0.22118)
# 04/03/2020 16:37:26 [INFO]: Epoch: 05, VAE loss: (17.1123, 13.81243), Discriminator loss: (0.12127, 0.21975)
# 04/03/2020 16:37:45 [INFO]: Epoch: 06, VAE loss: (17.02373, 15.55868), Discriminator loss: (0.11844, 0.21231)
# 04/03/2020 16:38:03 [INFO]: Epoch: 07, VAE loss: (16.8892, 12.7126), Discriminator loss: (0.12169, 0.20947)
# 04/03/2020 16:38:21 [INFO]: Epoch: 08, VAE loss: (16.96369, 13.73157), Discriminator loss: (0.12525, 0.21222)
# 04/03/2020 16:38:39 [INFO]: Epoch: 09, VAE loss: (16.73348, 14.96723), Discriminator loss: (0.12228, 0.20992)
# 04/03/2020 16:38:58 [INFO]: Epoch: 10, VAE loss: (16.56678, 13.34575), Discriminator loss: (0.1236, 0.21075)
# 04/03/2020 16:39:16 [INFO]: Epoch: 11, VAE loss: (16.85595, 13.83344), Discriminator loss: (0.12167, 0.20706)
# 04/03/2020 16:39:34 [INFO]: Epoch: 12, VAE loss: (16.56715, 13.09379), Discriminator loss: (0.12173, 0.22261)
# 04/03/2020 16:39:52 [INFO]: Epoch: 13, VAE loss: (16.58138, 14.14464), Discriminator loss: (0.12108, 0.20857)
# 04/03/2020 16:40:10 [INFO]: Epoch: 14, VAE loss: (16.47594, 13.03985), Discriminator loss: (0.1239, 0.20607)
# 04/03/2020 16:40:29 [INFO]: Epoch: 15, VAE loss: (16.37066, 13.24349), Discriminator loss: (0.12763, 0.21629)
# 04/03/2020 16:40:47 [INFO]: Epoch: 16, VAE loss: (16.31273, 14.07195), Discriminator loss: (0.13038, 0.20819)
# 04/03/2020 16:41:05 [INFO]: Epoch: 17, VAE loss: (16.19778, 12.87911), Discriminator loss: (0.12448, 0.21308)
# 04/03/2020 16:41:23 [INFO]: Epoch: 18, VAE loss: (16.22005, 13.66292), Discriminator loss: (0.12915, 0.21401)
# 04/03/2020 16:41:41 [INFO]: Epoch: 19, VAE loss: (16.16562, 13.29956), Discriminator loss: (0.12632, 0.21)
# 04/03/2020 16:42:00 [INFO]: Epoch: 20, VAE loss: (16.00429, 13.08237), Discriminator loss: (0.12406, 0.21426)
# 04/03/2020 16:42:18 [INFO]: Epoch: 21, VAE loss: (16.16695, 14.08888), Discriminator loss: (0.12999, 0.20728)
# 04/03/2020 16:42:36 [INFO]: Epoch: 22, VAE loss: (16.0661, 12.92171), Discriminator loss: (0.1222, 0.21214)
# 04/03/2020 16:42:54 [INFO]: Epoch: 23, VAE loss: (15.99304, 14.23054), Discriminator loss: (0.12256, 0.21264)
# 04/03/2020 16:43:13 [INFO]: Epoch: 24, VAE loss: (15.92507, 13.43284), Discriminator loss: (0.12922, 0.21416)
# 04/03/2020 16:43:31 [INFO]: Epoch: 25, VAE loss: (15.92726, 13.70719), Discriminator loss: (0.12331, 0.21517)
# 04/03/2020 16:43:49 [INFO]: Epoch: 26, VAE loss: (15.84534, 13.21755), Discriminator loss: (0.12549, 0.20719)
# 04/03/2020 16:44:07 [INFO]: Epoch: 27, VAE loss: (15.75131, 16.23529), Discriminator loss: (0.12463, 0.22572)
# 04/03/2020 16:44:25 [INFO]: Epoch: 28, VAE loss: (15.83638, 12.06365), Discriminator loss: (0.13084, 0.21396)
# 04/03/2020 16:44:44 [INFO]: Epoch: 29, VAE loss: (15.81318, 13.15268), Discriminator loss: (0.12618, 0.20714)
# 04/03/2020 16:44:44 [INFO]: TRAINING FINISHED.
#
# 04/03/2020 16:44:44 [INFO]: TRAINING STARTED (n_epochs = 30).
# 04/03/2020 16:45:02 [INFO]: Epoch: 00, VAE loss: (15.5937, 12.09841), Discriminator loss: (0.12724, 0.20825)
# 04/03/2020 16:45:20 [INFO]: Epoch: 01, VAE loss: (15.6711, 12.58511), Discriminator loss: (0.1253, 0.21241)
# 04/03/2020 16:45:39 [INFO]: Epoch: 02, VAE loss: (15.53978, 13.37905), Discriminator loss: (0.12987, 0.20387)
# 04/03/2020 16:45:57 [INFO]: Epoch: 03, VAE loss: (15.60253, 14.10608), Discriminator loss: (0.13458, 0.21824)
# 04/03/2020 16:46:15 [INFO]: Epoch: 04, VAE loss: (15.45352, 12.32429), Discriminator loss: (0.13091, 0.21591)
# 04/03/2020 16:46:33 [INFO]: Epoch: 05, VAE loss: (15.56327, 13.24573), Discriminator loss: (0.1301, 0.20894)
# 04/03/2020 16:46:52 [INFO]: Epoch: 06, VAE loss: (15.32977, 13.4777), Discriminator loss: (0.12569, 0.21666)
# 04/03/2020 16:47:10 [INFO]: Epoch: 07, VAE loss: (15.5757, 14.14767), Discriminator loss: (0.12763, 0.2129)
# 04/03/2020 16:47:28 [INFO]: Epoch: 08, VAE loss: (15.55676, 13.02095), Discriminator loss: (0.12771, 0.21195)
# 04/03/2020 16:47:46 [INFO]: Epoch: 09, VAE loss: (15.37516, 13.11758), Discriminator loss: (0.13035, 0.21698)
# 04/03/2020 16:48:05 [INFO]: Epoch: 10, VAE loss: (15.22909, 13.08645), Discriminator loss: (0.13168, 0.20925)
# 04/03/2020 16:48:23 [INFO]: Epoch: 11, VAE loss: (15.32366, 12.9177), Discriminator loss: (0.13047, 0.21229)
# 04/03/2020 16:48:41 [INFO]: Epoch: 12, VAE loss: (15.32569, 12.64501), Discriminator loss: (0.12752, 0.21502)
# 04/03/2020 16:48:59 [INFO]: Epoch: 13, VAE loss: (15.2187, 14.19315), Discriminator loss: (0.12654, 0.2157)
# 04/03/2020 16:49:18 [INFO]: Epoch: 14, VAE loss: (15.2083, 12.12697), Discriminator loss: (0.12451, 0.21323)
# 04/03/2020 16:49:36 [INFO]: Epoch: 15, VAE loss: (15.24221, 11.91873), Discriminator loss: (0.13024, 0.21262)
# 04/03/2020 16:49:54 [INFO]: Epoch: 16, VAE loss: (15.04296, 12.1383), Discriminator loss: (0.12389, 0.21391)
# 04/03/2020 16:50:12 [INFO]: Epoch: 17, VAE loss: (15.15402, 13.37746), Discriminator loss: (0.12718, 0.20618)
# 04/03/2020 16:50:31 [INFO]: Epoch: 18, VAE loss: (15.01384, 13.14193), Discriminator loss: (0.13036, 0.21791)
# 04/03/2020 16:50:49 [INFO]: Epoch: 19, VAE loss: (14.95831, 12.96096), Discriminator loss: (0.12966, 0.20822)
# 04/03/2020 16:51:07 [INFO]: Epoch: 20, VAE loss: (15.01014, 12.13726), Discriminator loss: (0.12885, 0.21201)
# 04/03/2020 16:51:25 [INFO]: Epoch: 21, VAE loss: (15.05257, 13.67143), Discriminator loss: (0.13427, 0.21102)
# 04/03/2020 16:51:44 [INFO]: Epoch: 22, VAE loss: (15.02903, 12.77517), Discriminator loss: (0.13269, 0.20991)
# 04/03/2020 16:52:02 [INFO]: Epoch: 23, VAE loss: (14.97154, 12.48974), Discriminator loss: (0.13192, 0.20802)
# 04/03/2020 16:52:20 [INFO]: Epoch: 24, VAE loss: (15.0068, 13.29717), Discriminator loss: (0.13201, 0.20914)
# 04/03/2020 16:54:29 [INFO]: Epoch: 01, VAE loss: (14.72802, 14.64637), Discriminator loss: (0.13156, 0.21238)
# 04/03/2020 16:54:47 [INFO]: Epoch: 02, VAE loss: (14.7452, 13.37378), Discriminator loss: (0.13214, 0.20929)
# 04/03/2020 16:55:05 [INFO]: Epoch: 03, VAE loss: (14.69531, 12.7143), Discriminator loss: (0.13305, 0.20616)
# 04/03/2020 16:55:23 [INFO]: Epoch: 04, VAE loss: (14.74857, 13.68343), Discriminator loss: (0.12796, 0.20681)
# 04/03/2020 16:55:42 [INFO]: Epoch: 05, VAE loss: (14.61392, 12.94323), Discriminator loss: (0.13024, 0.21264)
# 04/03/2020 16:56:00 [INFO]: Epoch: 06, VAE loss: (14.7146, 12.8263), Discriminator loss: (0.12952, 0.20645)
# 04/03/2020 16:56:18 [INFO]: Epoch: 07, VAE loss: (14.65769, 13.05046), Discriminator loss: (0.1312, 0.20822)
# 04/03/2020 16:56:37 [INFO]: Epoch: 08, VAE loss: (14.63409, 12.92563), Discriminator loss: (0.12828, 0.20647)
# 04/03/2020 16:56:55 [INFO]: Epoch: 09, VAE loss: (14.55069, 13.66618), Discriminator loss: (0.1331, 0.20623)
# 04/03/2020 16:57:13 [INFO]: Epoch: 10, VAE loss: (14.52728, 13.00357), Discriminator loss: (0.12808, 0.20301)
# 04/03/2020 16:57:32 [INFO]: Epoch: 11, VAE loss: (14.43618, 11.94028), Discriminator loss: (0.13501, 0.20861)
# 04/03/2020 16:57:50 [INFO]: Epoch: 12, VAE loss: (14.57794, 13.52437), Discriminator loss: (0.13529, 0.20897)
# 04/03/2020 16:58:08 [INFO]: Epoch: 13, VAE loss: (14.46641, 12.35858), Discriminator loss: (0.1293, 0.21464)
# 04/03/2020 16:58:27 [INFO]: Epoch: 14, VAE loss: (14.55621, 13.63965), Discriminator loss: (0.12652, 0.21081)
# 04/03/2020 16:58:45 [INFO]: Epoch: 15, VAE loss: (14.49299, 12.89933), Discriminator loss: (0.13747, 0.20599)
# 04/03/2020 16:59:04 [INFO]: Epoch: 16, VAE loss: (14.55828, 13.21317), Discriminator loss: (0.13213, 0.20757)
# 04/03/2020 16:59:22 [INFO]: Epoch: 17, VAE loss: (14.52649, 13.41688), Discriminator loss: (0.14298, 0.21029)
# 04/03/2020 16:59:40 [INFO]: Epoch: 18, VAE loss: (14.50354, 13.67985), Discriminator loss: (0.12921, 0.20958)
# 04/03/2020 16:59:59 [INFO]: Epoch: 19, VAE loss: (14.37189, 13.60201), Discriminator loss: (0.14077, 0.21538)
# 04/03/2020 17:00:17 [INFO]: Epoch: 20, VAE loss: (14.39703, 14.23505), Discriminator loss: (0.13649, 0.20983)
# 04/03/2020 17:00:35 [INFO]: Epoch: 21, VAE loss: (14.43657, 13.95363), Discriminator loss: (0.13328, 0.20804)
# 04/03/2020 17:00:54 [INFO]: Epoch: 22, VAE loss: (14.50466, 14.32129), Discriminator loss: (0.12807, 0.2123)
# 04/03/2020 17:01:12 [INFO]: Epoch: 23, VAE loss: (14.4183, 13.96349), Discriminator loss: (0.13823, 0.20819)
# 04/03/2020 17:01:30 [INFO]: Epoch: 24, VAE loss: (14.16986, 12.55131), Discriminator loss: (0.1323, 0.20625)
# 04/03/2020 17:01:49 [INFO]: Epoch: 25, VAE loss: (14.32093, 14.72212), Discriminator loss: (0.13508, 0.21343)
# 04/03/2020 17:02:07 [INFO]: Epoch: 26, VAE loss: (14.26553, 14.48496), Discriminator loss: (0.13331, 0.20943)
# 04/03/2020 17:02:26 [INFO]: Epoch: 27, VAE loss: (14.31964, 13.79482), Discriminator loss: (0.13929, 0.2103)
# 04/03/2020 17:02:44 [INFO]: Epoch: 28, VAE loss: (14.30648, 14.39076), Discriminator loss: (0.13224, 0.20331)
# 04/03/2020 17:03:02 [INFO]: Epoch: 29, VAE loss: (14.34525, 13.40834), Discriminator loss: (0.13319, 0.20958)
# 04/03/2020 17:03:02 [INFO]: TRAINING FINISHED.
#
# 04/03/2020 17:03:03 [INFO]: TRAINING STARTED (n_epochs = 30).
# 04/03/2020 17:03:21 [INFO]: Epoch: 00, VAE loss: (14.25299, 12.4568), Discriminator loss: (0.13047, 0.20429)
# 04/03/2020 17:03:40 [INFO]: Epoch: 01, VAE loss: (14.21372, 13.06478), Discriminator loss: (0.13775, 0.21335)
# 04/03/2020 17:04:01 [INFO]: Epoch: 02, VAE loss: (14.05505, 13.44381), Discriminator loss: (0.13512, 0.20829)
# 04/03/2020 17:04:31 [INFO]: Epoch: 03, VAE loss: (14.23086, 12.49205), Discriminator loss: (0.12998, 0.20518)
# 04/03/2020 17:04:49 [INFO]: Epoch: 04, VAE loss: (14.17963, 12.52739), Discriminator loss: (0.13628, 0.21296)
# 04/03/2020 17:05:07 [INFO]: Epoch: 05, VAE loss: (14.08199, 14.33035), Discriminator loss: (0.1318, 0.20872)
# 04/03/2020 17:05:25 [INFO]: Epoch: 06, VAE loss: (14.08889, 13.20955), Discriminator loss: (0.1358, 0.21067)
# 04/03/2020 17:05:43 [INFO]: Epoch: 07, VAE loss: (13.97338, 13.46763), Discriminator loss: (0.13205, 0.21057)
# 04/03/2020 17:06:01 [INFO]: Epoch: 08, VAE loss: (14.27947, 13.95929), Discriminator loss: (0.13997, 0.20907)
# 04/03/2020 17:06:19 [INFO]: Epoch: 09, VAE loss: (14.11925, 14.38724), Discriminator loss: (0.12996, 0.20966)
# 04/03/2020 17:06:37 [INFO]: Epoch: 10, VAE loss: (14.09076, 12.87929), Discriminator loss: (0.14454, 0.20474)
# 04/03/2020 17:06:55 [INFO]: Epoch: 11, VAE loss: (13.98148, 14.14404), Discriminator loss: (0.13251, 0.21185)
# 04/03/2020 17:07:13 [INFO]: Epoch: 12, VAE loss: (14.00074, 13.40959), Discriminator loss: (0.13246, 0.21125)
# 04/03/2020 17:07:31 [INFO]: Epoch: 13, VAE loss: (14.08366, 12.71996), Discriminator loss: (0.13649, 0.2102)
# 04/03/2020 17:07:49 [INFO]: Epoch: 14, VAE loss: (13.95529, 12.75894), Discriminator loss: (0.14013, 0.21221)
# 04/03/2020 17:08:07 [INFO]: Epoch: 15, VAE loss: (13.95957, 14.37754), Discriminator loss: (0.12969, 0.21031)
# 04/03/2020 17:08:25 [INFO]: Epoch: 16, VAE loss: (13.93982, 13.96496), Discriminator loss: (0.13524, 0.20961)
# 04/03/2020 17:08:43 [INFO]: Epoch: 17, VAE loss: (14.03609, 13.56505), Discriminator loss: (0.13745, 0.20744)
# 04/03/2020 17:09:02 [INFO]: Epoch: 18, VAE loss: (13.92549, 12.5797), Discriminator loss: (0.13824, 0.20975)
# 04/03/2020 17:09:20 [INFO]: Epoch: 19, VAE loss: (13.87852, 12.92725), Discriminator loss: (0.134, 0.21479)
# 04/03/2020 17:09:38 [INFO]: Epoch: 20, VAE loss: (14.08771, 13.18296), Discriminator loss: (0.14104, 0.21068)
# 04/03/2020 17:09:56 [INFO]: Epoch: 21, VAE loss: (13.94497, 13.82182), Discriminator loss: (0.1383, 0.21229)
# 04/03/2020 17:10:14 [INFO]: Epoch: 22, VAE loss: (13.92073, 12.86009), Discriminator loss: (0.1381, 0.21386)
# 04/03/2020 17:10:32 [INFO]: Epoch: 23, VAE loss: (13.85712, 13.88235), Discriminator loss: (0.13904, 0.20666)
# 04/03/2020 17:10:50 [INFO]: Epoch: 24, VAE loss: (13.92856, 14.59058), Discriminator loss: (0.14125, 0.21246)
# 04/03/2020 17:11:08 [INFO]: Epoch: 25, VAE loss: (13.91661, 14.78989), Discriminator loss: (0.13204, 0.21194)
# 04/03/2020 17:11:27 [INFO]: Epoch: 26, VAE loss: (13.88478, 13.00581), Discriminator loss: (0.13685, 0.20669)
# 04/03/2020 17:11:45 [INFO]: Epoch: 27, VAE loss: (13.78988, 12.41021), Discriminator loss: (0.14096, 0.21518)
# 04/03/2020 17:12:03 [INFO]: Epoch: 28, VAE loss: (13.8239, 12.56681), Discriminator loss: (0.13938, 0.21169)
# 04/03/2020 17:12:21 [INFO]: Epoch: 29, VAE loss: (13.8375, 13.56336), Discriminator loss: (0.13219, 0.21506)
# 04/03/2020 17:12:21 [INFO]: TRAINING FINISHED.
#
# [0.507, 0.491, 0.505, 0.495, 0.5048333333333334]
# [tensor(14.6047, grad_fn=<DivBackward0>), tensor(13.1527, grad_fn=<DivBackward0>), tensor(13.4079, grad_fn=<DivBackward0>), tensor(13.4083, grad_fn=<DivBackward0>), tensor(13.5634, grad_fn=<DivBackward0>)]

# %%
print(np.mean(accuracies))
print(torch.mean(torch.stack(val_losses)))
# Out:
# 0.5005666666666667
# tensor(13.6274, grad_fn=<MeanBackward0>)
